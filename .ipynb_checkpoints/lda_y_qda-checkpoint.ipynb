# %%
load('.RData')

# %%
library(ggplot2)
library(tidyverse)
library(ggpubr)
library(scatterplot3d)
library(reshape2)
library(MASS)
library(caret)
library(klaR)
# Out:
# ── Attaching packages ───────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ✔ purrr   0.3.4
# ── Conflicts ──────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# Loading required package: lattice
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:purrr’:
#
#     lift

# %%
fit_control <- trainControl(## 10-fold CV
                           method = "repeatedcv",
                           number = 10,
                           ## repeated ten times
                           repeats = 10,
                           classProbs=TRUE)

# %%
head(df)
# Out:
#    MouseID Genotype Treatment Behavior class DYRK1A_N  ITSN1_N   BDNF_N
# 76 3415_1  c        m         CS       cCSm  0.6497813 0.8286964 0.4058618
# 77 3415_2  c        m         CS       cCSm  0.6164807 0.8419742 0.3885837
# 78 3415_3  c        m         CS       cCSm  0.6374243 0.8528818 0.4005615
# 79 3415_4  c        m         CS       cCSm  0.5768145 0.7553900 0.3483463
# 80 3415_5  c        m         CS       cCSm  0.5425448 0.7579173 0.3500507
# 81 3415_6  c        m         CS       cCSm  0.5699176 0.7610777 0.3439100
#    NR1_N    NR2A_N   ⋯ SHH_N     BAD_N     BCL2_N    pS6_N     pCFOS_N
# 76 2.921435 5.167979 ⋯ 0.2397524 0.1390524 0.1129261 0.1320008 0.1293628
# 77 2.862575 5.194163 ⋯ 0.2490305 0.1337874 0.1216068 0.1390077 0.1430844
# 78 2.968155 5.350820 ⋯ 0.2479560 0.1423236 0.1302614 0.1348037 0.1476734
# 79 2.624901 4.727509 ⋯ 0.2332252 0.1336368 0.1073210 0.1189823 0.1212896
# 80 2.634509 4.735602 ⋯ 0.2444693 0.1333582 0.1128511 0.1286353 0.1426175
# 81 2.598085 4.764640 ⋯ 0.2475161 0.1358669 0.1100969 0.1279185 0.1338177
#    SYP_N     H3AcK18_N EGR1_N    H3MeK4_N  CaNA_N
# 76 0.4869115 0.1251522 0.1468649 0.1435166 1.627181
# 77 0.4678333 0.1128567 0.1611316 0.1457194 1.562096
# 78 0.4625013 0.1164328 0.1605935 0.1428788 1.571868
# 79 0.4791095 0.1028311 0.1442380 0.1416812 1.646608
# 80 0.4383545 0.1106140 0.1556674 0.1464082 1.607631
# 81 0.4613140 0.1142573 0.1559240 0.1421386 1.506520

# %%
df.sc <- as.data.frame(scale(df[, 6:76]))
df.sc$class <- df$class

# %%
head(df.sc)
# Out:
#    DYRK1A_N  ITSN1_N   BDNF_N    NR1_N     NR2A_N   pAKT_N      pBRAF_N
# 76 1.4354052 1.1251078 1.7038378 1.7016883 1.498598 -0.45013336  0.04750683
# 77 1.2316066 1.1977746 1.3798520 1.5417567 1.526958 -0.02800773 -0.30300959
# 78 1.3597811 1.2574695 1.6044502 1.8286351 1.696631 -0.40817510 -0.08536979
# 79 0.9888511 0.7239172 0.6253502 0.8959572 1.021533 -0.48341117 -0.55988101
# 80 0.7791214 0.7377485 0.6573099 0.9220636 1.030299 -0.36310325 -0.38377434
# 81 0.9466421 0.7550449 0.5421644 0.8230932 1.061750 -0.53348743 -0.43217951
#    pCAMKII_N  pCREB_N    pELK_N    ⋯ pCASP9_N   PSD95_N   SNCA_N
# 76 0.07715826  0.8617900 0.7611259 ⋯ 0.43518233 0.8750045  0.52375904
# 77 0.01942401  0.3541356 0.5018878 ⋯ 0.33573395 0.5482443  0.82156434
# 78 0.13967757  0.3894623 0.9532052 ⋯ 0.55128261 0.8779193 -0.03108825
# 79 0.11363556 -0.3933946 0.3493655 ⋯ 0.02745104 0.6576668 -0.53037739
# 80 0.18120182 -0.3893765 0.4161708 ⋯ 0.15971046 0.6739395 -0.26159288
# 81 0.16058906 -0.4239905 0.5288693 ⋯ 0.38155438 0.6517214 -0.28087480
#    Ubiquitin_N pGSK3B_Tyr216_N SHH_N     BAD_N      BCL2_N      pS6_N
# 76 -0.47323068 1.459926        0.4153460 -0.5753739 -0.68100997  0.83688429
# 77  0.05908699 1.387076        0.7427802 -0.7765282 -0.31096225  1.33008413
# 78  0.04859342 1.535779        0.7048586 -0.4503911  0.05797222  1.03417298
# 79 -0.96929031 1.249133        0.1849941 -0.7822819 -0.91994880 -0.07946734
# 80 -0.51174262 1.376878        0.5818095 -0.7929272 -0.68420841  0.59999493
# 81 -0.24997555 1.635044        0.6893360 -0.6970798 -0.80161808  0.54953940
#    class
# 76 cCSm
# 77 cCSm
# 78 cCSm
# 79 cCSm
# 80 cCSm
# 81 cCSm

# %%
set.seed(99)
index <- createDataPartition(df.sc$class, p = 0.70, list = FALSE)
train_data <- df.sc[index, ]
test_data <- df.sc[-index, ]
sprintf("The trainining set contains %d rows", nrow(train_data))
sprintf("The test set contains %d rows", nrow(test_data))
# Out:
# [1] "The trainining set contains 389 rows"
# [1] "The test set contains 163 rows"

# %%
#El modelo da error por variables coliniares.
#eliminamos las variables con alta correlacion
correlationMatrix <- cor(df.sc[, 1:71])
highlyCorrelated <- findCorrelation(correlationMatrix, cutoff=0.9)
highCorrelatedColumns <- colnames(correlationMatrix[, highlyCorrelated])
highCorrelatedColumns
train_data <- train_data[, !colnames(train_data) %in% c(highCorrelatedColumns, class)]
test_data <- test_data[, !colnames(test_data) %in% c(highCorrelatedColumns, class)]
# Out:
# [1] "NR1_N"    "pNR2B_N"  "ARC_N"    "ITSN1_N"  "DYRK1A_N" "BRAF_N"

# %%
table(train_data$class)
train_balanced <- upSample(x = train_data, y = train_data$class)
train_balanced <- train_balanced[, !(colnames(train_balanced) %in% c("Class"))]

table(train_balanced$class)
# Out:
# cCSm cCSs cSCm cSCs tCSm tCSs tSCm tSCs
#   32   53   42   53   63   53   42   51
# cCSm cCSs cSCm cSCs tCSm tCSs tSCm tSCs
#   63   63   63   63   63   63   63   63

# %%
lda_model <- train(class ~ ., 
                   data = train_balanced, 
                   method = 'lda', 
                   trControl = fit_control)
lda_model
# Out:
# Linear Discriminant Analysis
#
# 504 samples
#  65 predictor
#   8 classes: 'cCSm', 'cCSs', 'cSCm', 'cSCs', 'tCSm', 'tCSs', 'tSCm', 'tSCs'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold, repeated 10 times)
# Summary of sample sizes: 455, 451, 453, 456, 451, 453, ...
# Resampling results:
#
#   Accuracy   Kappa
#   0.9942125  0.9933822

# %%
lda_preds <- predict(lda_model, newdata = test_data)
confusionMatrix(lda_preds, test_data$class)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction cCSm cCSs cSCm cSCs tCSm tCSs tSCm tSCs
#       cCSm   13    0    0    0    1    0    0    0
#       cCSs    0   22    0    0    0    0    0    0
#       cSCm    0    0   18    0    0    0    0    0
#       cSCs    0    0    0   22    0    0    0    0
#       tCSm    0    0    0    0   26    0    0    0
#       tCSs    0    0    0    0    0   22    0    0
#       tSCm    0    0    0    0    0    0   18    0
#       tSCs    0    0    0    0    0    0    0   21
#
# Overall Statistics
#
#                Accuracy : 0.9939
#                  95% CI : (0.9663, 0.9998)
#     No Information Rate : 0.1656
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.993
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: cCSm Class: cCSs Class: cSCm Class: cSCs
# Sensitivity              1.00000       1.000      1.0000       1.000
# Specificity              0.99333       1.000      1.0000       1.000
# Pos Pred Value           0.92857       1.000      1.0000       1.000
# Neg Pred Value           1.00000       1.000      1.0000       1.000
# Prevalence               0.07975       0.135      0.1104       0.135
# Detection Rate           0.07975       0.135      0.1104       0.135
# Detection Prevalence     0.08589       0.135      0.1104       0.135
# Balanced Accuracy        0.99667       1.000      1.0000       1.000
#                      Class: tCSm Class: tCSs Class: tSCm Class: tSCs
# Sensitivity               0.9630       1.000      1.0000      1.0000
# Specificity               1.0000       1.000      1.0000      1.0000
# Pos Pred Value            1.0000       1.000      1.0000      1.0000
# Neg Pred Value            0.9927       1.000      1.0000      1.0000
# Prevalence                0.1656       0.135      0.1104      0.1288
# Detection Rate            0.1595       0.135      0.1104      0.1288
# Detection Prevalence      0.1595       0.135      0.1104      0.1288
# Balanced Accuracy         0.9815       1.000      1.0000      1.0000

# %%
# Warning message:
# “model fit failed for Fold01.Rep01: parameter=none Error in qda.default(x, grouping, ...) : 
#   some group is too small for 'qda'

# %%
qda_model <- train(class ~ ., 
                   data = train_balanced, 
                   method = 'qda', 
                   trControl = fit_control)
qda_model
# Out:
# Warning message:
# “model fit failed for Fold01.Rep01: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold02.Rep01: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold03.Rep01: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold04.Rep01: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold05.Rep01: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold06.Rep01: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold07.Rep01: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold08.Rep01: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold09.Rep01: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold10.Rep01: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold01.Rep02: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold02.Rep02: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold03.Rep02: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold04.Rep02: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold05.Rep02: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold06.Rep02: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold07.Rep02: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold08.Rep02: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold09.Rep02: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold10.Rep02: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold01.Rep03: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold02.Rep03: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold03.Rep03: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold04.Rep03: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold05.Rep03: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold06.Rep03: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold07.Rep03: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold08.Rep03: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold09.Rep03: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold10.Rep03: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold01.Rep04: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold02.Rep04: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold03.Rep04: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold04.Rep04: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold05.Rep04: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold06.Rep04: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold07.Rep04: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold08.Rep04: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold09.Rep04: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold10.Rep04: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold01.Rep05: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold02.Rep05: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold03.Rep05: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold04.Rep05: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold05.Rep05: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold06.Rep05: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold07.Rep05: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold08.Rep05: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold09.Rep05: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold10.Rep05: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold01.Rep06: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold02.Rep06: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold03.Rep06: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold04.Rep06: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold05.Rep06: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold06.Rep06: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold07.Rep06: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold08.Rep06: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold09.Rep06: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold10.Rep06: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold01.Rep07: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold02.Rep07: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold03.Rep07: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold04.Rep07: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold05.Rep07: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold06.Rep07: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold07.Rep07: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold08.Rep07: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold09.Rep07: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold10.Rep07: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold01.Rep08: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold02.Rep08: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold03.Rep08: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold04.Rep08: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold05.Rep08: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold06.Rep08: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold07.Rep08: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold08.Rep08: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold09.Rep08: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold10.Rep08: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold01.Rep09: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold02.Rep09: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold03.Rep09: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold04.Rep09: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold05.Rep09: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold06.Rep09: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold07.Rep09: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold08.Rep09: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold09.Rep09: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold10.Rep09: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold01.Rep10: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold02.Rep10: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold03.Rep10: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold04.Rep10: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold05.Rep10: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold06.Rep10: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold07.Rep10: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold08.Rep10: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold09.Rep10: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message:
# “model fit failed for Fold10.Rep10: parameter=none Error in qda.default(x, grouping, ...) :
#   some group is too small for 'qda'
# ”
# Warning message in nominalTrainWorkflow(x = x, y = y, wts = weights, info = trainInfo, :
# “There were missing values in resampled performance measures.”
# Something is wrong; all the Accuracy metric values are missing:
#     Accuracy       Kappa
#  Min.   : NA   Min.   : NA
#  1st Qu.: NA   1st Qu.: NA
#  Median : NA   Median : NA
#  Mean   :NaN   Mean   :NaN
#  3rd Qu.: NA   3rd Qu.: NA
#  Max.   : NA   Max.   : NA
#  NA's   :1     NA's   :1
# Error: Stopping
# Traceback:
#
# 1. train(class ~ ., data = train_balanced, method = "qda", trControl = fit_control)
# 2. train.formula(class ~ ., data = train_balanced, method = "qda",
#  .     trControl = fit_control)
# 3. train(x, y, weights = w, ...)
# 4. train.default(x, y, weights = w, ...)
# 5. stop("Stopping", call. = FALSE)

# %%
qda_preds <- predict(qda_model, newdata = test_data)
confusionMatrix(qda_preds, test_data$class)
# Out:
# Error in predict(qda_model, newdata = test_data): objeto 'qda_model' no encontrado
# Traceback:
#
# 1. predict(qda_model, newdata = test_data)
