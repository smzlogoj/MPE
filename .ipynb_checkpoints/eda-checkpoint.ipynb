# %% [markdown]
# ### Análisis exploratorio de los datos.

# %%
library(ggplot2)
library(ggpubr)
library(naniar)

# %%
df <- read.csv('data/Data_Cortex_Nuclear.csv')
proteinas <- colnames(df[, 2:78])
df <- df[, c('MouseID', 'Genotype', 'Treatment', 'Behavior', 'class', proteinas)]
df$Genotype <- ifelse(df$Genotype == 'Control', 'c', 't')
df$Treatment <- ifelse(df$Treatment == 'Memantine', 'm', 's')
df$Behavior <- as.factor(gsub('/', '', df$Behavior))
df$class <- paste0(df$Genotype, df$Behavior, df$Treatment)
df$Genotype <- as.factor(df$Genotype)
df$Treatment <- as.factor(df$Treatment)
df$Behavior <- as.factor(df$Behavior)
df$class <- as.factor(df$class)
head(df)
# Out:
#   MouseID Genotype Treatment Behavior class DYRK1A_N  ITSN1_N   BDNF_N
# 1 309_1   c        m         CS       cCSm  0.5036439 0.7471932 0.4301753
# 2 309_2   c        m         CS       cCSm  0.5146171 0.6890635 0.4117703
# 3 309_3   c        m         CS       cCSm  0.5091831 0.7302468 0.4183088
# 4 309_4   c        m         CS       cCSm  0.4421067 0.6170762 0.3586263
# 5 309_5   c        m         CS       cCSm  0.4349402 0.6174298 0.3588022
# 6 309_6   c        m         CS       cCSm  0.4475064 0.6281758 0.3673881
#   NR1_N    NR2A_N   ⋯ SHH_N     BAD_N     BCL2_N pS6_N     pCFOS_N   SYP_N
# 1 2.816329 5.990152 ⋯ 0.1888517 0.1226520 NA     0.1063052 0.1083359 0.4270992
# 2 2.789514 5.685038 ⋯ 0.2004036 0.1166822 NA     0.1065922 0.1043154 0.4415813
# 3 2.687201 5.622059 ⋯ 0.1936845 0.1185082 NA     0.1083031 0.1062193 0.4357769
# 4 2.466947 4.979503 ⋯ 0.1921119 0.1327812 NA     0.1031838 0.1112620 0.3916910
# 5 2.365785 4.718679 ⋯ 0.2056042 0.1299541 NA     0.1047838 0.1106939 0.4341538
# 6 2.385939 4.807635 ⋯ 0.1904695 0.1315752 NA     0.1064762 0.1094457 0.4398331
#   H3AcK18_N EGR1_N    H3MeK4_N  CaNA_N
# 1 0.1147832 0.1317900 0.1281856 1.675652
# 2 0.1119735 0.1351030 0.1311187 1.743610
# 3 0.1118829 0.1333618 0.1274311 1.926427
# 4 0.1304053 0.1474442 0.1469011 1.700563
# 5 0.1184814 0.1403143 0.1483799 1.839730
# 6 0.1166572 0.1407664 0.1421804 1.816389

# %%
### Eliminar proteinas con % alto de NA
#df <- df[, !colnames(df) %in% c('BAD_N', 'BCL2_N', 'pCFOS_N', 'H3AcK18_N', 'EGR1_N', 'H3MeK4_N')]
df <- df[complete.cases(df), ]

# %%
vis_miss(df)
# Out:
# Warning message:
# “`gather_()` was deprecated in tidyr 1.2.0.
# Please use `gather()` instead.”
# plot without title

# %%
createViolinPlot <- function(variable, clase){
    p1 <- ggplot(df, aes_string(x = clase, y = variable, fill = clase)) + 
            geom_violin() +
            theme_bw() +
            theme(axis.title.x = element_blank()) +
            coord_flip()
    p1
}

# %%
createDensityPlot <- function(variable, clase){
    p1 <- ggplot(df, aes_string(x = variable)) + 
            geom_density(aes_string(colour = clase)) +
            theme_bw()
    p1
}

# %%
createFig <- function(variable, clase){
    ggarrange(createViolinPlot(variable, clase), 
              createDensityPlot(variable, clase), 
              nrow = 2, ncol = 1, common.legend  = TRUE, legend = 'top', align = 'hv')
}

# %%
createFig('NR2A_N', 'class')
# Out:
# plot without title

# %%
createFig('NR2A_N', 'Genotype')
# Out:
# plot without title

# %%
save.image()

# %%
head(df)
# Out:
#    MouseID Genotype Treatment Behavior class DYRK1A_N  ITSN1_N   BDNF_N
# 76 3415_1  c        m         CS       cCSm  0.6497813 0.8286964 0.4058618
# 77 3415_2  c        m         CS       cCSm  0.6164807 0.8419742 0.3885837
# 78 3415_3  c        m         CS       cCSm  0.6374243 0.8528818 0.4005615
# 79 3415_4  c        m         CS       cCSm  0.5768145 0.7553900 0.3483463
# 80 3415_5  c        m         CS       cCSm  0.5425448 0.7579173 0.3500507
# 81 3415_6  c        m         CS       cCSm  0.5699176 0.7610777 0.3439100
#    NR1_N    NR2A_N   ⋯ SHH_N     BAD_N     BCL2_N    pS6_N     pCFOS_N
# 76 2.921435 5.167979 ⋯ 0.2397524 0.1390524 0.1129261 0.1320008 0.1293628
# 77 2.862575 5.194163 ⋯ 0.2490305 0.1337874 0.1216068 0.1390077 0.1430844
# 78 2.968155 5.350820 ⋯ 0.2479560 0.1423236 0.1302614 0.1348037 0.1476734
# 79 2.624901 4.727509 ⋯ 0.2332252 0.1336368 0.1073210 0.1189823 0.1212896
# 80 2.634509 4.735602 ⋯ 0.2444693 0.1333582 0.1128511 0.1286353 0.1426175
# 81 2.598085 4.764640 ⋯ 0.2475161 0.1358669 0.1100969 0.1279185 0.1338177
#    SYP_N     H3AcK18_N EGR1_N    H3MeK4_N  CaNA_N
# 76 0.4869115 0.1251522 0.1468649 0.1435166 1.627181
# 77 0.4678333 0.1128567 0.1611316 0.1457194 1.562096
# 78 0.4625013 0.1164328 0.1605935 0.1428788 1.571868
# 79 0.4791095 0.1028311 0.1442380 0.1416812 1.646608
# 80 0.4383545 0.1106140 0.1556674 0.1464082 1.607631
# 81 0.4613140 0.1142573 0.1559240 0.1421386 1.506520
